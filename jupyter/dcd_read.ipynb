# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
df = pd.read_csv("../data/car_1.csv")

# %%
df
# Out:
#                                   车名  官方指导价     厂商   级别 能源类型     上市时间  \
# 0                迈腾 2024款 300TSI 尊享型    NaN  一汽-大众  中型车   汽油  2024.07
# 1                迈腾 2024款 380TSI 尊贵版    NaN  一汽-大众  中型车   汽油  2024.07
# 2                迈腾 2024款 380TSI 至尊版    NaN  一汽-大众  中型车   汽油  2024.07
# 3  迈腾 2024款 200万辆众享款 280TSI DSG舒适众享款    NaN  一汽-大众  中型车   汽油  2024.07
# 4  迈腾 2024款 200万辆众享款 330TSI DSG豪华众享款    NaN  一汽-大众  中型车   汽油  2024.07
# 5    迈腾 2023款 200万辆纪念版 280TSI DSG舒适型    NaN  一汽-大众  中型车   汽油  2022.10
# 6    迈腾 2023款 200万辆纪念版 280TSI DSG领先型    NaN  一汽-大众  中型车   汽油  2022.10
# 7    迈腾 2023款 200万辆纪念版 330TSI DSG领先型    NaN  一汽-大众  中型车   汽油  2022.10
# 8    迈腾 2023款 200万辆纪念版 330TSI DSG豪华型    NaN  一汽-大众  中型车   汽油  2022.10
# 9    迈腾 2023款 200万辆纪念版 380TSI DSG旗舰型    NaN  一汽-大众  中型车   汽油  2022.10
#
#              发动机  最大功率(kW)  最大扭矩(N·m)    变速箱  ... 矩阵大灯包 至尊特别版  舒享包  舒享音乐包  \
# 0  1.5T 160马力 L4       118        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# ...

# %%
00:110:120]

# %%
middle_columns
# Out:
#    导航辅助驾驶                                             辅助驾驶级别 自动泊车入位  循迹倒车  \
# 0     NaN  ○ L1级 ○ L1级 ○ L2级 ● L2级 ● L2级 ● L2级 ○ L2级 ○ L2...    NaN   NaN
# 1     NaN                                              ● L2级    ○选配   NaN
# 2     NaN                                              ● L2级    ●标配   NaN
# 3     NaN                                              ○ L1级    NaN   NaN
# 4     NaN                                              ● L2级    NaN   NaN
# 5     NaN                                              ○ L1级    NaN   NaN
# 6     NaN                                              ○ L2级    NaN   NaN
# 7     NaN                                              ○ L2级    NaN   NaN
# 8     NaN                                              ● L2级    NaN   NaN
# 9     NaN                                              ● L2级    ●标配   NaN
#
#    记忆泊车 自动驻车(AUTOHOLD) 上坡辅助(HAC)  陡坡缓降(HDC) 发动机启停技术  可变悬挂调节
# 0   NaN            ●标配       ●标配        NaN     ●标配     NaN
# ...
