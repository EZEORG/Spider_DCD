# %%
import pandas as pd
import numpy as np
from pandas import DataFrame

# %%
df = pd.read_csv("../dcd_data/car_1.csv")

# %%
df
# Out:
#                                   车名   官方指导价     厂商   级别 能源类型     上市时间  \
# 0                迈腾 2024款 300TSI 尊享型  17.99万  一汽-大众  中型车   汽油  2024.07
# 1                迈腾 2024款 380TSI 尊贵版  20.99万  一汽-大众  中型车   汽油  2024.07
# 2                迈腾 2024款 380TSI 至尊版  24.69万  一汽-大众  中型车   汽油  2024.07
# 3  迈腾 2024款 200万辆众享款 280TSI DSG舒适众享款  17.49万  一汽-大众  中型车   汽油  2024.07
# 4  迈腾 2024款 200万辆众享款 330TSI DSG豪华众享款  20.69万  一汽-大众  中型车   汽油  2024.07
# 5    迈腾 2023款 200万辆纪念版 280TSI DSG舒适型  18.69万  一汽-大众  中型车   汽油  2022.10
# 6    迈腾 2023款 200万辆纪念版 280TSI DSG领先型  19.59万  一汽-大众  中型车   汽油  2022.10
# 7    迈腾 2023款 200万辆纪念版 330TSI DSG领先型  21.19万  一汽-大众  中型车   汽油  2022.10
# 8    迈腾 2023款 200万辆纪念版 330TSI DSG豪华型  22.69万  一汽-大众  中型车   汽油  2022.10
# 9    迈腾 2023款 200万辆纪念版 380TSI DSG旗舰型  25.39万  一汽-大众  中型车   汽油  2022.10
#
#              发动机  最大功率(kW)  最大扭矩(N·m)    变速箱  ... 矩阵大灯包 至尊特别版  舒享包  舒享音乐包  \
# 0  1.5T 160马力 L4       118        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 1  2.0T 220马力 L4       162        350  7挡双离合  ...   NaN   NaN  NaN    NaN
# 2  2.0T 220马力 L4       162        350  7挡双离合  ...   NaN   NaN  NaN    NaN
# 3  1.4T 150马力 L4       110        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 4  2.0T 186马力 L4       137        320  7挡双离合  ...   NaN   NaN  NaN    NaN
# 5  1.4T 150马力 L4       110        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 6  1.4T 150马力 L4       110        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 7  2.0T 186马力 L4       137        320  7挡双离合  ...   NaN   NaN  NaN    NaN
# 8  2.0T 186马力 L4       137        320  7挡双离合  ...   NaN   NaN  NaN    NaN
# 9  2.0T 220马力 L4       162        350  7挡双离合  ...   NaN   NaN  NaN    NaN
#
#    选装包12 选装包2 选装包5  选装包7  选装包8  驾驶记忆包
# 0    NaN  NaN  NaN   NaN   NaN    NaN
# 1    NaN  NaN  NaN   NaN   NaN    NaN
# 2    NaN  NaN  NaN   NaN   NaN    NaN
# 3    NaN  NaN  NaN   NaN   NaN    NaN
# 4    NaN  NaN  NaN   NaN   NaN    NaN
# 5    NaN  NaN  NaN   NaN   NaN    NaN
# 6    NaN  NaN  NaN   NaN   NaN    NaN
# 7    NaN  NaN  NaN   NaN   NaN    NaN
# 8    NaN  NaN  NaN   NaN   NaN    NaN
# 9    NaN  NaN  NaN   NaN   NaN    NaN
#
# [10 rows x 286 columns]

# %%
middle_columns = df.iloc[:, 276:286]#查看4到6列

# %%
middle_columns
# Out:
#    矩阵大灯包  至尊特别版  舒享包  舒享音乐包  选装包12  选装包2  选装包5  选装包7  选装包8  驾驶记忆包
# 0    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 1    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 2    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 3    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 4    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 5    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 6    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 7    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 8    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN
# 9    NaN    NaN  NaN    NaN    NaN   NaN   NaN   NaN   NaN    NaN

# %%
df = pd.read_csv("../dcd_data/car_2.csv")

# %%
df
# Out:
#                                   车名   官方指导价       厂商    级别     能源类型    上市时间  \
# 0          奥迪A6L 2024款 40 TFSI 豪华致雅型  42.79万  一汽-大众奥迪  中大型车       汽油  2023.1
# 1          奥迪A6L 2024款 40 TFSI 豪华动感型  42.79万  一汽-大众奥迪  中大型车       汽油  2023.1
# 2          奥迪A6L 2024款 45 TFSI 臻选致雅型  45.49万  一汽-大众奥迪  中大型车       汽油  2023.1
# 3          奥迪A6L 2024款 45 TFSI 臻选动感型  45.49万  一汽-大众奥迪  中大型车       汽油  2023.1
# 4  奥迪A6L 2024款 45 TFSI quattro 臻选致雅型  47.99万  一汽-大众奥迪  中大型车       汽油  2023.1
# 5  奥迪A6L 2024款 45 TFSI quattro 臻选动感型  47.99万  一汽-大众奥迪  中大型车       汽油  2023.1
# 6  奥迪A6L 2024款 45 TFSI quattro 尊享致雅型  49.98万  一汽-大众奥迪  中大型车       汽油  2023.1
# 7  奥迪A6L 2024款 45 TFSI quattro 尊享动感型  49.98万  一汽-大众奥迪  中大型车       汽油  2023.1
# 8  奥迪A6L 2024款 55 TFSI quattro 尊享动感型  55.89万  一汽-大众奥迪  中大型车  48V轻混系统  2023.1
# 9  奥迪A6L 2024款 55 TFSI quattro 旗舰致雅型  65.68万  一汽-大众奥迪  中大型车  48V轻混系统  2023.1
#
#                    发动机  最大功率(kW) 发动机最大功率(kW)  电动机最大功率(kW)  ...  高精度地图  \
# 0        2.0T 190马力 L4       140  140(190Ps)          NaN  ...    NaN
# 1        2.0T 190马力 L4       140  140(190Ps)          NaN  ...    NaN
# 2        2.0T 245马力 L4       180  180(245Ps)          NaN  ...    NaN
# 3        2.0T 245马力 L4       180  180(245Ps)          NaN  ...    NaN
# 4        2.0T 245马力 L4       180  180(245Ps)          NaN  ...    NaN
# 5        2.0T 245马力 L4       180  180(245Ps)          NaN  ...    NaN
# 6        2.0T 245马力 L4       180  180(245Ps)          NaN  ...    NaN
# 7        2.0T 245马力 L4       180  180(245Ps)          NaN  ...    NaN
# 8  3.0T 340马力 V6 48V轻混       250  250(340Ps)          NaN  ...    NaN
# 9  3.0T 340马力 V6 48V轻混       250  250(340Ps)          NaN  ...    NaN
#
#    哨兵（千里眼）模式  V2X通讯            定制选装 前排舒适型座椅 城市行车辅助包  奥迪侧向辅助及奥迪预安全后部版  奥迪手机盒子  \
# 0        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 1        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 2        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 3        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 4        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 5        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 6        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 7        NaN    NaN  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 8        NaN    ●标配  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
# 9        NaN    ●标配  可选外观、内饰、轮毂、制动器     NaN     NaN              NaN     NaN
#
#    奥迪高清矩阵LED大灯 深色玻璃包
# 0          NaN   NaN
# 1          NaN   NaN
# 2          NaN   NaN
# 3          NaN   NaN
# 4          NaN   NaN
# 5          NaN   NaN
# 6          NaN   NaN
# 7          NaN   NaN
# 8          NaN   NaN
# 9          NaN   NaN
#
# [10 rows x 275 columns]

# %%
df = pd.read_csv("../dcd_data/car_3.csv")

# %%
df
# Out:
#                           车名    官方指导价    厂商    级别 能源类型     上市时间  \
# 0        朗逸 2024款 1.5L 自动得逸版   12.09万  上汽大众  紧凑型车   汽油  2023.09
# 1        朗逸 2024款 1.5L 自动满逸版   12.79万  上汽大众  紧凑型车   汽油  2023.09
# 2       朗逸 2024款 1.5L 自动五百万版   13.09万  上汽大众  紧凑型车   汽油  2023.09
# 3     朗逸 2024款 1.5L 自动星空五百万版   13.09万  上汽大众  紧凑型车   汽油  2023.09
# 4     朗逸 2024款 300TSI DSG满逸版   13.89万  上汽大众  紧凑型车   汽油  2023.09
# 5   朗逸 2024款 300TSI DSG星空满逸版   13.89万  上汽大众  紧凑型车   汽油  2023.09
# 6   朗逸 2024款 300TSI DSG星空领先版   14.39万  上汽大众  紧凑型车   汽油  2023.08
# 7     朗逸 2024款 300TSI DSG永逸版   15.19万  上汽大众  紧凑型车   汽油  2023.09
# 8   朗逸 2024款 300TSI DSG星空永逸版   15.19万  上汽大众  紧凑型车   汽油  2023.09
# 9   朗逸 2023款 新锐 1.5L 自动出众新逸版   7.999万  上汽大众  紧凑型车   汽油  2024.04
# 10  朗逸 2023款 新锐 1.5L 自动出众新愿版   8.799万  上汽大众  紧凑型车   汽油  2024.04
# 11    朗逸 2023款 新锐 1.5L 自动新逸版   9.999万  上汽大众  紧凑型车   汽油  2023.06
# 12    朗逸 2023款 新锐 1.5L 自动新愿版  10.999万  上汽大众  紧凑型车   汽油  2023.06
#
#               发动机  最大功率(kW)  最大扭矩(N·m)     变速箱  ... 车内摄影头像素 超声波雷达数量(个)  \
# 0   1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 1   1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 2   1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 3   1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 4   1.5T 160马力 L4       118        250   7挡双离合  ...     NaN         ●4
# 5   1.5T 160马力 L4       118        250   7挡双离合  ...     NaN         ●4
# 6   1.5T 160马力 L4       118        250   7挡双离合  ...     NaN         ●8
# 7   1.5T 160马力 L4       118        250   7挡双离合  ...     NaN         ●8
# 8   1.5T 160马力 L4       118        250   7挡双离合  ...     NaN         ●8
# 9   1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 10  1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 11  1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
# 12  1.5L 110马力 L4        81        141  6挡手自一体  ...     NaN         ●4
#
#     毫米波雷达数量(个)  亚米级高精定位系统  高精度地图 哨兵（千里眼）模式 V2X通讯            定制选装  互联准备系统  \
# 0           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 1           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 2           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 3           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 4           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 5           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 6           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 7           ●3        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 8           ●3        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 9           ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 10          ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 11          ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
# 12          ●1        NaN    NaN       NaN   NaN  可选外观、内饰、轮毂、制动器     NaN
#
#     酷黑运动套件选装包
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9         NaN
# 10        NaN
# 11        NaN
# 12        NaN
#
# [13 rows x 262 columns]

# %%
df = pd.read_csv("../dcd_data/car_4.csv")

# %%
df
# Out:
#                                   车名   官方指导价     厂商   级别 能源类型     上市时间  \
# 0                迈腾 2024款 300TSI 尊享型  17.99万  一汽-大众  中型车   汽油  2024.07
# 1                迈腾 2024款 380TSI 尊贵版  20.99万  一汽-大众  中型车   汽油  2024.07
# 2                迈腾 2024款 380TSI 至尊版  24.69万  一汽-大众  中型车   汽油  2024.07
# 3  迈腾 2024款 200万辆众享款 280TSI DSG舒适众享款  17.49万  一汽-大众  中型车   汽油  2024.07
# 4  迈腾 2024款 200万辆众享款 330TSI DSG豪华众享款  20.69万  一汽-大众  中型车   汽油  2024.07
# 5    迈腾 2023款 200万辆纪念版 280TSI DSG舒适型  18.69万  一汽-大众  中型车   汽油  2022.10
# 6    迈腾 2023款 200万辆纪念版 280TSI DSG领先型  19.59万  一汽-大众  中型车   汽油  2022.10
# 7    迈腾 2023款 200万辆纪念版 330TSI DSG领先型  21.19万  一汽-大众  中型车   汽油  2022.10
# 8    迈腾 2023款 200万辆纪念版 330TSI DSG豪华型  22.69万  一汽-大众  中型车   汽油  2022.10
# 9    迈腾 2023款 200万辆纪念版 380TSI DSG旗舰型  25.39万  一汽-大众  中型车   汽油  2022.10
#
#              发动机  最大功率(kW)  最大扭矩(N·m)    变速箱  ... 矩阵大灯包 至尊特别版  舒享包  舒享音乐包  \
# 0  1.5T 160马力 L4       118        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 1  2.0T 220马力 L4       162        350  7挡双离合  ...   NaN   NaN  NaN    NaN
# 2  2.0T 220马力 L4       162        350  7挡双离合  ...   NaN   NaN  NaN    NaN
# 3  1.4T 150马力 L4       110        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 4  2.0T 186马力 L4       137        320  7挡双离合  ...   NaN   NaN  NaN    NaN
# 5  1.4T 150马力 L4       110        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 6  1.4T 150马力 L4       110        250  7挡双离合  ...   NaN   NaN  NaN    NaN
# 7  2.0T 186马力 L4       137        320  7挡双离合  ...   NaN   NaN  NaN    NaN
# 8  2.0T 186马力 L4       137        320  7挡双离合  ...   NaN   NaN  NaN    NaN
# 9  2.0T 220马力 L4       162        350  7挡双离合  ...   NaN   NaN  NaN    NaN
#
#    选装包12 选装包2 选装包5  选装包7  选装包8  驾驶记忆包
# 0    NaN  NaN  NaN   NaN   NaN    NaN
# 1    NaN  NaN  NaN   NaN   NaN    NaN
# 2    NaN  NaN  NaN   NaN   NaN    NaN
# 3    NaN  NaN  NaN   NaN   NaN    NaN
# 4    NaN  NaN  NaN   NaN   NaN    NaN
# 5    NaN  NaN  NaN   NaN   NaN    NaN
# 6    NaN  NaN  NaN   NaN   NaN    NaN
# 7    NaN  NaN  NaN   NaN   NaN    NaN
# 8    NaN  NaN  NaN   NaN   NaN    NaN
# 9    NaN  NaN  NaN   NaN   NaN    NaN
#
# [10 rows x 286 columns]
